# %%
import nltk

# %%
#nltk.download()

# %%
paragraph="""Yava was the son of a sage who practiced hard penance to get the blessings of Indra, the King of Devas. He tortured his body with austerities and thus awakened the sympathy of Indra. Indra came before him and asked why he was hurting his body.

Yava answered: “I wish to be a great scholar of the Vedas. It takes a long time to learn the Vedas from a teacher. I am practicing austerities to get that knowledge directly. Bless me.”

Indra smiled and said: “Son, you are on the wrong path. Return home, find a good teacher, and learn the Vedas from him. Austerity is not the way to learn; the path is study and study alone.” With these words, Indra went away.

But Yava would not give up. He did his course of spiritual practice (austerities, penance) with even greater effort. Indra again came before Yava and warned him again. Yava announced that if his prayer was not answered, he would cut off his arms and legs one by one and offer them to the fire. No, he would never give up. He continued his penance. One morning, during his austerities, when he went to bathe in the holy Gangā River, he saw an old man on the bank throwing handfuls of sand into the river.

“Old man, what are you doing?” asked Yava.

 The old man replied: “I am going to build a dam across the river so people can cross the river easily. See how difficult it is now to cross it. Useful work, isn’t it? ”

Yava laughed and said: “What a fool you must be to think you can build a dam across this mighty river with your handfuls of sand! Go home and do some other useful work.”

The old man said: “Is my work more foolish than yours of learning the Vedas, not by study, but by austerities?”

Yava now knew that the old man was Indra. Yava earnestly begged Indra to grant him learning as a personal wish.

Indra blessed him and comforted Yava with the following words: “I grant you the wish you want. Go and read the Vedas; you will become learned.”

Yava studied the Vedas and became a great scholar of the Vedas.

         

The secret of success is to keep thinking about what you want all the time and never give up until you get what you want. Do not let negative thoughts, such as delaying to start work, laziness, and carelessness stand in your way. """

# %% [markdown]
# # Tokenization

# %%
#Tokenize sentences
sentences=nltk.sent_tokenize(paragraph)
sentences
# Out:
# ['Yava was the son of a sage who practiced hard penance to get the blessings of Indra, the King of Devas.',
#  'He tortured his body with austerities and thus awakened the sympathy of Indra.',
#  'Indra came before him and asked why he was hurting his body.',
#  'Yava answered: “I wish to be a great scholar of the Vedas.',
#  'It takes a long time to learn the Vedas from a teacher.',
#  'I am practicing austerities to get that knowledge directly.',
#  'Bless me.”\n\nIndra smiled and said: “Son, you are on the wrong path.',
#  'Return home, find a good teacher, and learn the Vedas from him.',
#  'Austerity is not the way to learn; the path is study and study alone.” With these words, Indra went away.',
#  'But Yava would not give up.',
#  'He did his course of spiritual practice (austerities, penance) with even greater effort.',
#  'Indra again came before Yava and warned him again.',
#  'Yava announced that if his prayer was not answered, he would cut off his arms and legs one by one and offer them to the fire.',
#  'No, he would never give up.',
#  'He continued his penance.',
#  'One morning, during his austerities, when he went to bathe in the holy Gangā River, he saw an old man on the bank throwing handfuls of sand into the river.',
#  '“Old man, what are you doing?” asked Yava.',
#  'The old man replied: “I am going to build a dam across the river so people can cross the river easily.',
#  'See how difficult it is now to cross it.',
#  'Useful work, isn’t it?',
#  '”\n\nYava laughed and said: “What a fool you must be to think you can build a dam across this mighty river with your handfuls of sand!',
#  'Go home and do some other useful work.”\n\nThe old man said: “Is my work more foolish than yours of learning the Vedas, not by study, but by austerities?”\n\nYava now knew that the old man was Indra.',
#  'Yava earnestly begged Indra to grant him learning as a personal wish.',
#  'Indra blessed him and comforted Yava with the following words: “I grant you the wish you want.',
#  'Go and read the Vedas; you will become learned.”\n\nYava studied the Vedas and became a great scholar of the Vedas.',
#  'The secret of success is to keep thinking about what you want all the time and never give up until you get what you want.',
#  'Do not let negative thoughts, such as delaying to start work, laziness, and carelessness stand in your way.']

# %%
#Tokenize words
words=nltk.word_tokenize(paragraph)
words
# Out:
# ['Yava',
#  'was',
#  'the',
#  'son',
#  'of',
#  'a',
#  'sage',
#  'who',
#  'practiced',
#  'hard',
#  'penance',
#  'to',
#  'get',
#  'the',
#  'blessings',
#  'of',
#  'Indra',
#  ',',
#  'the',
#  'King',
#  'of',
#  'Devas',
#  '.',
#  'He',
#  'tortured',
#  'his',
#  'body',
#  'with',
#  'austerities',
#  'and',
#  'thus',
#  'awakened',
#  'the',
#  'sympathy',
#  'of',
#  'Indra',
#  '.',
#  'Indra',
#  'came',
#  'before',
#  'him',
#  'and',
#  'asked',
#  'why',
#  'he',
#  'was',
#  'hurting',
#  'his',
#  'body',
#  '.',
#  'Yava',
#  'answered',
#  ':',
#  '“',
#  'I',
#  'wish',
#  'to',
#  'be',
#  'a',
#  'great',
#  'scholar',
#  'of',
#  'the',
#  'Vedas',
#  '.',
#  'It',
#  'takes',
#  'a',
#  'long',
#  'time',
#  'to',
#  'learn',
#  'the',
#  'Vedas',
#  'from',
#  'a',
#  'teacher',
#  '.',
#  'I',
#  'am',
#  'practicing',
#  'austerities',
#  'to',
#  'get',
#  'that',
#  'knowledge',
#  'directly',
#  '.',
#  'Bless',
#  'me.',
#  '”',
#  'Indra',
#  'smiled',
#  'and',
#  'said',
#  ':',
#  '“',
#  'Son',
#  ',',
#  'you',
#  'are',
#  'on',
#  'the',
#  'wrong',
#  'path',
#  '.',
#  'Return',
#  'home',
#  ',',
#  'find',
#  'a',
#  'good',
#  'teacher',
#  ',',
#  'and',
#  'learn',
#  'the',
#  'Vedas',
#  'from',
#  'him',
#  '.',
#  'Austerity',
#  'is',
#  'not',
#  'the',
#  'way',
#  'to',
#  'learn',
#  ';',
#  'the',
#  'path',
#  'is',
#  'study',
#  'and',
#  'study',
#  'alone.',
#  '”',
#  'With',
#  'these',
#  'words',
#  ',',
#  'Indra',
#  'went',
#  'away',
#  '.',
#  'But',
#  'Yava',
#  'would',
#  'not',
#  'give',
#  'up',
#  '.',
#  'He',
#  'did',
#  'his',
#  'course',
#  'of',
#  'spiritual',
#  'practice',
#  '(',
#  'austerities',
#  ',',
#  'penance',
#  ')',
#  'with',
#  'even',
#  'greater',
#  'effort',
#  '.',
#  'Indra',
#  'again',
#  'came',
#  'before',
#  'Yava',
#  'and',
#  'warned',
#  'him',
#  'again',
#  '.',
#  'Yava',
#  'announced',
#  'that',
#  'if',
#  'his',
#  'prayer',
#  'was',
#  'not',
#  'answered',
#  ',',
#  'he',
#  'would',
#  'cut',
#  'off',
#  'his',
#  'arms',
#  'and',
#  'legs',
#  'one',
#  'by',
#  'one',
#  'and',
#  'offer',
#  'them',
#  'to',
#  'the',
#  'fire',
#  '.',
#  'No',
#  ',',
#  'he',
#  'would',
#  'never',
#  'give',
#  'up',
#  '.',
#  'He',
#  'continued',
#  'his',
#  'penance',
#  '.',
#  'One',
#  'morning',
#  ',',
#  'during',
#  'his',
#  'austerities',
#  ',',
#  'when',
#  'he',
#  'went',
#  'to',
#  'bathe',
#  'in',
#  'the',
#  'holy',
#  'Gangā',
#  'River',
#  ',',
#  'he',
#  'saw',
#  'an',
#  'old',
#  'man',
#  'on',
#  'the',
#  'bank',
#  'throwing',
#  'handfuls',
#  'of',
#  'sand',
#  'into',
#  'the',
#  'river',
#  '.',
#  '“',
#  'Old',
#  'man',
#  ',',
#  'what',
#  'are',
#  'you',
#  'doing',
#  '?',
#  '”',
#  'asked',
#  'Yava',
#  '.',
#  'The',
#  'old',
#  'man',
#  'replied',
#  ':',
#  '“',
#  'I',
#  'am',
#  'going',
#  'to',
#  'build',
#  'a',
#  'dam',
#  'across',
#  'the',
#  'river',
#  'so',
#  'people',
#  'can',
#  'cross',
#  'the',
#  'river',
#  'easily',
#  '.',
#  'See',
#  'how',
#  'difficult',
#  'it',
#  'is',
#  'now',
#  'to',
#  'cross',
#  'it',
#  '.',
#  'Useful',
#  'work',
#  ',',
#  'isn',
#  '’',
#  't',
#  'it',
#  '?',
#  '”',
#  'Yava',
#  'laughed',
#  'and',
#  'said',
#  ':',
#  '“',
#  'What',
#  'a',
#  'fool',
#  'you',
#  'must',
#  'be',
#  'to',
#  'think',
#  'you',
#  'can',
#  'build',
#  'a',
#  'dam',
#  'across',
#  'this',
#  'mighty',
#  'river',
#  'with',
#  'your',
#  'handfuls',
#  'of',
#  'sand',
#  '!',
#  'Go',
#  'home',
#  'and',
#  'do',
#  'some',
#  'other',
#  'useful',
#  'work.',
#  '”',
#  'The',
#  'old',
#  'man',
#  'said',
#  ':',
#  '“',
#  'Is',
#  'my',
#  'work',
#  'more',
#  'foolish',
#  'than',
#  'yours',
#  'of',
#  'learning',
#  'the',
#  'Vedas',
#  ',',
#  'not',
#  'by',
#  'study',
#  ',',
#  'but',
#  'by',
#  'austerities',
#  '?',
#  '”',
#  'Yava',
#  'now',
#  'knew',
#  'that',
#  'the',
#  'old',
#  'man',
#  'was',
#  'Indra',
#  '.',
#  'Yava',
#  'earnestly',
#  'begged',
#  'Indra',
#  'to',
#  'grant',
#  'him',
#  'learning',
#  'as',
#  'a',
#  'personal',
#  'wish',
#  '.',
#  'Indra',
#  'blessed',
#  'him',
#  'and',
#  'comforted',
#  'Yava',
#  'with',
#  'the',
#  'following',
#  'words',
#  ':',
#  '“',
#  'I',
#  'grant',
#  'you',
#  'the',
#  'wish',
#  'you',
#  'want',
#  '.',
#  'Go',
#  'and',
#  'read',
#  'the',
#  'Vedas',
#  ';',
#  'you',
#  'will',
#  'become',
#  'learned.',
#  '”',
#  'Yava',
#  'studied',
#  'the',
#  'Vedas',
#  'and',
#  'became',
#  'a',
#  'great',
#  'scholar',
#  'of',
#  'the',
#  'Vedas',
#  '.',
#  'The',
#  'secret',
#  'of',
#  'success',
#  'is',
#  'to',
#  'keep',
#  'thinking',
#  'about',
#  'what',
#  'you',
#  'want',
#  'all',
#  'the',
#  'time',
#  'and',
#  'never',
#  'give',
#  'up',
#  'until',
#  'you',
#  'get',
#  'what',
#  'you',
#  'want',
#  '.',
#  'Do',
#  'not',
#  'let',
#  'negative',
#  'thoughts',
#  ',',
#  'such',
#  'as',
#  'delaying',
#  'to',
#  'start',
#  'work',
#  ',',
#  'laziness',
#  ',',
#  'and',
#  'carelessness',
#  'stand',
#  'in',
#  'your',
#  'way',
#  '.']

# %% [markdown]
# # Stemming and Stopwords

# %%
from nltk.stem import PorterStemmer
from nltk.corpus import stopwords

# %%
stemmer=PorterStemmer()

# %%
#Stemming
for i in range(len(sentences)):
    words=nltk.word_tokenize(sentences[i])
    words=[stemmer.stem(word) for word in words if word not in set(stopwords.words('english'))]
    sentences[i]=' '.join(words)

# %%
sentences
# Out:
# ['yava son sage practic hard penanc get bless indra , king deva .',
#  'He tortur bodi auster thu awaken sympathi indra .',
#  'indra came ask hurt bodi .',
#  'yava answer : “ I wish great scholar veda .',
#  'It take long time learn veda teacher .',
#  'I practic auster get knowledg directli .',
#  'bless . ” indra smile said : “ son , wrong path .',
#  'return home , find good teacher , learn veda .',
#  'auster way learn ; path studi studi alon . ” word , indra went away .',
#  'yava would give .',
#  'He cour spiritu practic ( auster , penanc ) even greater effort .',
#  'indra came yava warn .',
#  'yava announc prayer answer , would cut arm leg one one offer fire .',
#  'No , would never give .',
#  'He continu penanc .',
#  'one morn , auster , went bath holi gangā river , saw old man bank throw hand sand river .',
#  '“ old man , ? ” ask yava .',
#  'old man repli : “ I go build dam across river peopl cross river easili .',
#  'see difficult cross .',
#  'use work , ’ ?',
#  '” yava laugh said : “ fool must think build dam across mighti river hand sand !',
#  'Go home use work . ” old man said : “ Is work foolish learn veda , studi , auster ? ” yava knew old man indra .',
#  'yava earnestli beg indra grant learn person wish .',
#  'indra bless comfort yava follow word : “ I grant wish want .',
#  'Go read veda ; becom learn . ” yava studi veda becam great scholar veda .',
#  'secret success keep think want time never give get want .',
#  'Do let neg thought , delay start work , lazi , careless stand way .']

# %% [markdown]
# # Lemmatization

# %%
from nltk.stem import WordNetLemmatizer
from nltk.corpus import stopwords

# %%
sentences=nltk.sent_tokenize(paragraph)
sentences
lemmatizer=WordNetLemmatizer()

# %%
#Lemmatization
for i in range(len(sentences)):
    words=nltk.word_tokenize(sentences[i])
    words=[lemmatizer.lemmatize(word) for word in words if word not in set(stopwords.words('english'))]
    sentences[i]=' '.join(words)

# %%
sentences
# Out:
# ['Yava son sage practiced hard penance get blessing Indra , King Devas .',
#  'He tortured body austerity thus awakened sympathy Indra .',
#  'Indra came asked hurting body .',
#  'Yava answered : “ I wish great scholar Vedas .',
#  'It take long time learn Vedas teacher .',
#  'I practicing austerity get knowledge directly .',
#  'Bless me. ” Indra smiled said : “ Son , wrong path .',
#  'Return home , find good teacher , learn Vedas .',
#  'Austerity way learn ; path study study alone. ” With word , Indra went away .',
#  'But Yava would give .',
#  'He course spiritual practice ( austerity , penance ) even greater effort .',
#  'Indra came Yava warned .',
#  'Yava announced prayer answered , would cut arm leg one one offer fire .',
#  'No , would never give .',
#  'He continued penance .',
#  'One morning , austerity , went bathe holy Gangā River , saw old man bank throwing handful sand river .',
#  '“ Old man , ? ” asked Yava .',
#  'The old man replied : “ I going build dam across river people cross river easily .',
#  'See difficult cross .',
#  'Useful work , ’ ?',
#  '” Yava laughed said : “ What fool must think build dam across mighty river handful sand !',
#  'Go home useful work. ” The old man said : “ Is work foolish learning Vedas , study , austerity ? ” Yava knew old man Indra .',
#  'Yava earnestly begged Indra grant learning personal wish .',
#  'Indra blessed comforted Yava following word : “ I grant wish want .',
#  'Go read Vedas ; become learned. ” Yava studied Vedas became great scholar Vedas .',
#  'The secret success keep thinking want time never give get want .',
#  'Do let negative thought , delaying start work , laziness , carelessness stand way .']
